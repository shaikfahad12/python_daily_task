# %% [markdown]
#  # types of oops concept

# %%
#without 

class cat:
    def sound(self):
        print("meowwwwww")
class dog:
    def sound(self):
        print("bhauuuuuuuuuuuu")

class cow:
        print("mooooo")
# Out:
# mooooo

# %%
#take the parent class as compamy : company
# take two args : __name, __desg
#get private data 
#make two abstract method :
#1 : work 
#2 : salary
#display all info 
name,role,work,salary

#create two child :employee, manager

# %%
class BankAccount:
    def __init__(self, owner, balance=0):
        self.owner = owner
        self.__balance = balance  # private attribute

    # Deposit money
    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: {amount}. New balance: {self.__balance}")
        else:
            print("Deposit amount must be greater than 0")


    def withdraw(self, amount):
        if amount <= 0:
            print("Withdrawal amount must be greater than 0")
        elif amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrawn: {amount}. New balance: {self.__balance}")
        else:
            print("Insufficient balance")

    def get_balance(self):
        return self.__balance


acc1 = BankAccount("Fahad", 1000)
acc2 = BankAccount("Neha", 500)

acc1.deposit(500)     
acc1.withdraw(200)    
acc1.withdraw(2000)     
acc1.deposit(-100)     

print(f"{acc1.owner}'s balance: {acc1.get_balance()}")
# Out:
# Deposited: 500. New balance: 1500
# Withdrawn: 200. New balance: 1300
# Insufficient balance
# Deposit amount must be greater than 0
# Fahad's balance: 1300
